# %%
from howfsc.scripts.jactest_mp import calculate_jacobian_multiprocessed
from howfsc.scripts.nulltest_gitl import nulling_test_gitl

jacout = "C:\\dansWork\\roman_cpp\\runs\\jacobians\\nfov_flat_jac_ful.fits"
calculate_jacobian_multiprocessed(output=jacout, mode = 'nfov_flat', proc=0)

jacpath = "C:\\dansWork\\roman_cpp\\runs\\jacobians"
fileout = "C:\\dansWork\\roman_cpp\\runs\\loop_nfov_flat\\fileout.log"
logfile = "C:\\dansWork\\roman_cpp\\runs\\loop_nfov_flat\\logging.log"
nulling_test_gitl(logfile=logfile, fileout=fileout, jacpath=jacpath)
# Out:
# mode = nfov_flat
# INFO:root:Begin Jacobian calculation
# INFO:root:multiprocessing using 24 processes
# INFO:root:setting os.environ[MKL_NUM_THREADS] 1 threads
# INFO:root:restoring os.environ['MKL_NUM_THREADS'] to previous value
# INFO:root:Jacobian calculation complete: elapsed time = 71.729846 secs
# INFO:root:Writing jac to: C:\dansWork\roman_cpp\runs\jacobians\nfov_flat_jac_ful.fits
# INFO:howfsc.gitl:-------------------------------
# INFO:howfsc.gitl:Begin howfsc_computation
# INFO:howfsc.gitl:Begin input checks
# INFO:howfsc.gitl:Iteration number: 1
# INFO:howfsc.gitl:Input checks complete
# INFO:howfsc.gitl:Building exposure-time calculator class
# INFO:howfsc.gitl:HOWFSC evaluated with Vmag = 2.25, type = O5
# INFO:howfsc.gitl:Wavelength 1 of 3
# INFO:howfsc.gitl:Get flux for this CFAM filter
# INFO:howfsc.gitl:Expect 4.72154e+06 photons/sec
# INFO:howfsc.gitl:DM setting 1 of 7
# INFO:howfsc.gitl:1. Separate image data from bad pixel map for all frames
# ...
