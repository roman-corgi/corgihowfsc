# %% [markdown]
# # Exposure times for TD1 alternate probing

# %%
import os
from astropy.io import fits
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
import numpy
import pandas as pd

norm = LogNorm(vmin=1e-2, vmax=3e2)

# %%
# First setup
loop1_fname = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-04-29_115549_corgisim_model'
# Factor 3 in get_initial_cam_params()
loop2_fname = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-04-29_140146_corgisim_model'
# Requested probe height 1e-6, NO factor 3 in get_initial_cam_params()
loop3_fname = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-04-29_144546_corgisim_model'
# Requested probe height 1e-7, NO factor 3 in get_initial_cam_params()
loop4_fname = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-04-29_150411_corgisim_model'
# Removed probe scaling entirely
loop5_fname = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-04-29_153422_corgisim_model'
# Scale factor hard coded to 0.1, updated corgisim to commit (on main): bfef275f3fb8df6514cc6eec41665df1341b3ad4
loop6_fname = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-04-29_155343_corgisim_model'
# Factor 3 back in get initial cam params
loop7_fname = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-04-29_160519_corgisim_model'
# Remi with Gaussian probes
remi_fname = '/Users/ilaginja/Nextcloud/Areas/RomanCPP/alternate_probes/2026-04-29_160546_corgisim_model_main_gaussian_remi'
# Factor 3 back in get initial cam params, and Gaussian probes now (1e-7)
loop8_fname = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-04-29_162355_corgisim_model'
# Factor 3 back in get initial cam params, and Gaussian probes now (1e-7), but min nframes=5
loop9_fname = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-05-01_164156_corgisim_model'
# Like previous but standard probes
loop10_fname = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-05-01_171452_corgisim_model'
# Crank up requested probe SNR for Gaussian probes to 30, rest like above
loop11_fname = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-05-01_172929_corgisim_model'
# Hard-coding Susan's EXCAM parameters into get_initial_cam_params() and running on Gaussian probes 
loop12_fname = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-05-01_172929_corgisim_model'
# Like previous line but standard probes 
loop13_fname = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-05-01_172929_corgisim_model'

## Second CPGS delivery with stronger probes (5e-7) -> original probed SNR of probedsnr=7 (in cstrat_nfov_band1.yaml)
# Gaussians at 5e-7
stronger1 = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-05-27_132926_corgisim_model'
# Defaults probes (sincs) at 1e-7 for sanity check
stronger2 = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-05-27_141942_corgisim_model'
# Default probes (sincs) at 5e-7
stronger3 = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-05-27_144406_corgisim_model'
# Gaussians at 1e-7 for sanity check
stronger4 = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-05-27_151621_corgisim_model'

## Second CPGS delivery with stronger probes (5e-7) -> higher probed SNR
# Gaussians at 5e-7 and SNR=12 (minimum for non-linearities to pop out in sinc probes)
stronger5 = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-05-27_162225_corgisim_model'
# Gaussians at 5e-7 and SNR=15
stronger6 = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-05-27_164331_corgisim_model'
# Default probes (sincs) at 5e-7 and SNR=15
stronger7 = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-05-27_183045_corgisim_model'

## Comparing min number of frames and resulting exposure times (probed SNR always 15, unprobed SNR always 5)
# Default probes with Nframe_min=3, 5e-7
run1 = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-06-10_162259_corgisim_model'
# Gaussian probes with Nframe_min=3, 5e-7
run2 = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-06-10_163546_corgisim_model'
###--->>>
# Gaussian probes with Nframe_min=5, 5e-7
run3 = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-06-10_164921_corgisim_model'
# Default probes with Nframe_min=5, 5e-7
run4 = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-06-10_170340_corgisim_model'
###---<<<
# Default probes with Nframe_min=3, 1e-7
run5 = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-06-10_180305_corgisim_model'
# Gaussian probes with Nframe_min=3, 1e-7
run6 = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-06-10_174904_corgisim_model'
# Gaussian probes with Nframe_min=5, 1e-7
run7 = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-06-10_173624_corgisim_model'
# Default probes with Nframe_min=5, 1e-7
run8 = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-06-10_171920_corgisim_model'
# Sanity check (compare to run4): probed SNR back to 7; default probes, NFrame_min=5, 5e-7
run9 = '/Users/ilaginja/data_repos/corgiloop_data/corgi-howfsc_gitl/2026-06-10_233526_corgisim_model'

# %%
loop_fname = run4
img_iter1_fname = os.path.join(loop_fname, 'iteration_0001/images.fits')
imgs_iter1 = fits.getdata(img_iter1_fname)
img_iter2_fname = os.path.join(loop_fname, 'iteration_0002/images.fits')
imgs_iter2 = fits.getdata(img_iter2_fname)
img_iter3_fname = os.path.join(loop_fname, 'iteration_0003/images.fits')
imgs_iter3 = fits.getdata(img_iter3_fname)

debug_history = pd.read_csv(os.path.join(loop_fname, 'debugging_history.csv'))

# %%
band = 3  # Choose: 1, 2 or 3

if band == 1:
    const = 0
elif band == 2:
    const = 1
elif band == 3:
    const = 2
else:
    raise ValueError('Not a valid imaging band')

# %%
# Print debug history
debug_history

# %%
col_width = 35
iteration = 0
print(f'Band {band} of 3')
print(f'Iteration {iteration+1}')
print('\n')
print(
    f"| {'Unprobed img':<{col_width}} | {'Probed img':<{col_width}} |\n"
    f"| {'-'*col_width} | {'-'*col_width} |\n"
    f"| {'Exposure time: ' + str(debug_history.loc[const+iteration*3, 'cam_nom_exptime']) + ' s':<{col_width}} | {'Exposure time: ' + str(debug_history.loc[const+iteration*3, 'cam_probe_exptime']) + ' s':<{col_width}} |\n"
    f"| {'Camera gain: ' + str(debug_history.loc[const+iteration*3, 'cam_nom_gain']):<{col_width}} | {'Camera gain: ' + str(debug_history.loc[const+iteration*3, 'cam_probe_gain']):<{col_width}} |\n"
    f"| {'Number of frames: ' + str(debug_history.loc[const+iteration*3, 'cam_nom_nframes']):<{col_width}} | {'Number of frames: ' + str(debug_history.loc[const+iteration*3, 'cam_probe_nframes']):<{col_width}} |"
)
print('\n')
print(f'Iteration duration: {debug_history.loc[const+iteration*3, 'this_iter_dur'] / 60} min')
print(f'Iteration duration with up/downlink overheads: {debug_history.loc[const+iteration*3, 'this_iter_dur_gitl'] / 60} min')

plt.figure(figsize=(18, 8))
plt.suptitle('Iteration 1')

imgs = imgs_iter1
plt.subplot(2, 4, 1)
plt.imshow(imgs[0], cmap='inferno', norm=norm)
plt.colorbar()
plt.subplot(2, 4, 2)
plt.imshow(imgs[1], cmap='inferno', norm=norm)
plt.colorbar()
plt.subplot(2, 4, 3)
plt.imshow(imgs[3], cmap='inferno', norm=norm)
plt.colorbar()
plt.subplot(2, 4, 4)
plt.imshow(imgs[5], cmap='inferno', norm=norm)
plt.colorbar()

plt.subplot(2, 4, 6)
plt.imshow(imgs[2], cmap='inferno', norm=norm)
plt.colorbar()
plt.subplot(2, 4, 7)
plt.imshow(imgs[4], cmap='inferno', norm=norm)
plt.colorbar()
plt.subplot(2, 4, 8)
plt.imshow(imgs[6], cmap='inferno', norm=norm)
plt.colorbar()

# %%
col_width = 35
iteration = 1
print(f'Band {band} of 3')
print(f'Iteration {iteration+1}')
print('\n')
print(
    f"| {'Unprobed img':<{col_width}} | {'Probed img':<{col_width}} |\n"
    f"| {'-'*col_width} | {'-'*col_width} |\n"
    f"| {'Exposure time: ' + str(debug_history.loc[const+iteration*3, 'cam_nom_exptime']) + ' s':<{col_width}} | {'Exposure time: ' + str(debug_history.loc[const+iteration*3, 'cam_probe_exptime']) + ' s':<{col_width}} |\n"
    f"| {'Camera gain: ' + str(debug_history.loc[const+iteration*3, 'cam_nom_gain']):<{col_width}} | {'Camera gain: ' + str(debug_history.loc[const+iteration*3, 'cam_probe_gain']):<{col_width}} |\n"
    f"| {'Number of frames: ' + str(debug_history.loc[const+iteration*3, 'cam_nom_nframes']):<{col_width}} | {'Number of frames: ' + str(debug_history.loc[const+iteration*3, 'cam_probe_nframes']):<{col_width}} |"
)
print('\n')
print(f'Iteration duration: {debug_history.loc[const+iteration*3, 'this_iter_dur'] / 60} min')
print(f'Iteration duration with up/downlink overheads: {debug_history.loc[const+iteration*3, 'this_iter_dur_gitl'] / 60} min')

plt.figure(figsize=(18, 8))
plt.suptitle('Iteration 2')

imgs = imgs_iter2
plt.subplot(2, 4, 1)
plt.imshow(imgs[0], cmap='inferno', norm=norm)
plt.colorbar()
plt.subplot(2, 4, 2)
plt.imshow(imgs[1], cmap='inferno', norm=norm)
plt.colorbar()
plt.subplot(2, 4, 3)
plt.imshow(imgs[3], cmap='inferno', norm=norm)
plt.colorbar()
plt.subplot(2, 4, 4)
plt.imshow(imgs[5], cmap='inferno', norm=norm)
plt.colorbar()

plt.subplot(2, 4, 6)
plt.imshow(imgs[2], cmap='inferno', norm=norm)
plt.colorbar()
plt.subplot(2, 4, 7)
plt.imshow(imgs[4], cmap='inferno', norm=norm)
plt.colorbar()
plt.subplot(2, 4, 8)
plt.imshow(imgs[6], cmap='inferno', norm=norm)
plt.colorbar()

# %%
col_width = 35
iteration = 2
print(f'Band {band} of 3')
print(f'Iteration {iteration+1}')
print('\n')
print(
    f"| {'Unprobed img':<{col_width}} | {'Probed img':<{col_width}} |\n"
    f"| {'-'*col_width} | {'-'*col_width} |\n"
    f"| {'Exposure time: ' + str(debug_history.loc[const+iteration*3, 'cam_nom_exptime']) + ' s':<{col_width}} | {'Exposure time: ' + str(debug_history.loc[const+iteration*3, 'cam_probe_exptime']) + ' s':<{col_width}} |\n"
    f"| {'Camera gain: ' + str(debug_history.loc[const+iteration*3, 'cam_nom_gain']):<{col_width}} | {'Camera gain: ' + str(debug_history.loc[const+iteration*3, 'cam_probe_gain']):<{col_width}} |\n"
    f"| {'Number of frames: ' + str(debug_history.loc[const+iteration*3, 'cam_nom_nframes']):<{col_width}} | {'Number of frames: ' + str(debug_history.loc[const+iteration*3, 'cam_probe_nframes']):<{col_width}} |"
)
print('\n')
print(f'Iteration duration: {debug_history.loc[const+iteration*3, 'this_iter_dur'] / 60} min')
print(f'Iteration duration with up/downlink overheads: {debug_history.loc[const+iteration*3, 'this_iter_dur_gitl'] / 60} min')

plt.figure(figsize=(18, 8))
plt.suptitle('Iteration 3')

imgs = imgs_iter3
plt.subplot(2, 4, 1)
plt.imshow(imgs[0], cmap='inferno', norm=norm)
plt.colorbar()
plt.subplot(2, 4, 2)
plt.imshow(imgs[1], cmap='inferno', norm=norm)
plt.colorbar()
plt.subplot(2, 4, 3)
plt.imshow(imgs[3], cmap='inferno', norm=norm)
plt.colorbar()
plt.subplot(2, 4, 4)
plt.imshow(imgs[5], cmap='inferno', norm=norm)
plt.colorbar()

plt.subplot(2, 4, 6)
plt.imshow(imgs[2], cmap='inferno', norm=norm)
plt.colorbar()
plt.subplot(2, 4, 7)
plt.imshow(imgs[4], cmap='inferno', norm=norm)
plt.colorbar()
plt.subplot(2, 4, 8)
plt.imshow(imgs[6], cmap='inferno', norm=norm)
plt.colorbar()

# %% [markdown]
# ## Comparisons

# %% [markdown]
# ### probed SNR = 7 (default)

# %%
data_paths = {"default_1e-7": stronger2, "gaussian_1e-7": stronger4, "default_5e-7": stronger3, "gaussian_5e-7": stronger1}
loop_data = {}

for loop, loop_fname in data_paths.items():
    img_iter1_fname = os.path.join(loop_fname, 'iteration_0001/images.fits')
    imgs_iter1 = fits.getdata(img_iter1_fname)
    img_iter2_fname = os.path.join(loop_fname, 'iteration_0002/images.fits')
    imgs_iter2 = fits.getdata(img_iter2_fname)
    img_iter3_fname = os.path.join(loop_fname, 'iteration_0003/images.fits')
    imgs_iter3 = fits.getdata(img_iter3_fname)
    
    debug_history = pd.read_csv(os.path.join(loop_fname, 'debugging_history.csv'))

    loop_data[loop] = {"img_it1": imgs_iter1, "img_it2": imgs_iter2, "img_it3": imgs_iter3, "debug_history": debug_history}

# %%
iteration = 0
band = 1   # out of 1, 2, or 3
col_width = 35

if band == 1:
    const = 0
elif band == 2:
    const = 1
elif band == 3:
    const ==2
else:
    raise ValueError('Not a valid imaging band')

for loop in loop_data.keys():
    debug_history = loop_data[loop]["debug_history"]
    print(f'{loop} at unprobedsnr=7 (default)')
    print(
        f"| {'Unprobed img':<{col_width}} | {'Probed img':<{col_width}} |\n"
        f"| {'-'*col_width} | {'-'*col_width} |\n"
        f"| {'Exposure time: ' + str(debug_history.loc[const+iteration*3, 'cam_nom_exptime']) + ' s':<{col_width}} | {'Exposure time: ' + str(debug_history.loc[const+iteration*3, 'cam_probe_exptime']) + ' s':<{col_width}} |\n"
        f"| {'Camera gain: ' + str(debug_history.loc[const+iteration*3, 'cam_nom_gain']):<{col_width}} | {'Camera gain: ' + str(debug_history.loc[const+iteration*3, 'cam_probe_gain']):<{col_width}} |\n"
        f"| {'Number of frames: ' + str(debug_history.loc[const+iteration*3, 'cam_nom_nframes']):<{col_width}} | {'Number of frames: ' + str(debug_history.loc[const+iteration*3, 'cam_probe_nframes']):<{col_width}} |"
    )
    print('\n')

# %% [markdown]
# ### Increase probed SNR to make non-linearities pop up in sinc probes images

# %%
data_paths = {"gaussian_5e-7_snr12": stronger5, "gaussian_5e-7_snr15": stronger6, "default_5e-7_snr15": stronger7}
loop_data = {}

for loop, loop_fname in data_paths.items():
    img_iter1_fname = os.path.join(loop_fname, 'iteration_0001/images.fits')
    imgs_iter1 = fits.getdata(img_iter1_fname)
    img_iter2_fname = os.path.join(loop_fname, 'iteration_0002/images.fits')
    imgs_iter2 = fits.getdata(img_iter2_fname)
    img_iter3_fname = os.path.join(loop_fname, 'iteration_0003/images.fits')
    imgs_iter3 = fits.getdata(img_iter3_fname)
    
    debug_history = pd.read_csv(os.path.join(loop_fname, 'debugging_history.csv'))

    loop_data[loop] = {"img_it1": imgs_iter1, "img_it2": imgs_iter2, "img_it3": imgs_iter3, "debug_history": debug_history}

# %%
iteration = 0
band = 1   # out of 1, 2, or 3
col_width = 35

if band == 1:
    const = 0
elif band == 2:
    const = 1
elif band == 3:
    const ==2
else:
    raise ValueError('Not a valid imaging band')

for loop in loop_data.keys():
    debug_history = loop_data[loop]["debug_history"]
    print(f'{loop}')
    print(
        f"| {'Unprobed img':<{col_width}} | {'Probed img':<{col_width}} |\n"
        f"| {'-'*col_width} | {'-'*col_width} |\n"
        f"| {'Exposure time: ' + str(debug_history.loc[const+iteration*3, 'cam_nom_exptime']) + ' s':<{col_width}} | {'Exposure time: ' + str(debug_history.loc[const+iteration*3, 'cam_probe_exptime']) + ' s':<{col_width}} |\n"
        f"| {'Camera gain: ' + str(debug_history.loc[const+iteration*3, 'cam_nom_gain']):<{col_width}} | {'Camera gain: ' + str(debug_history.loc[const+iteration*3, 'cam_probe_gain']):<{col_width}} |\n"
        f"| {'Number of frames: ' + str(debug_history.loc[const+iteration*3, 'cam_nom_nframes']):<{col_width}} | {'Number of frames: ' + str(debug_history.loc[const+iteration*3, 'cam_probe_nframes']):<{col_width}} |"
    )
    print('\n')

# %% [markdown]
# ## Total time sum

# %%
# From https://github.com/roman-corgi/corgi_ObsPlanning/blob/main/eetc_tutorials/eetc_tutorial_CPP_obs.ipynb
def rough_wall_clock(n_frames,
                     exp_t,
                     mode='continuous',
                     readout_t=0.264,
                     transfer_time=3.):
    """
    Compute the rough wall clock time for a given observation sequence.
    
    Computes the total exposure time including readout/transfer overheads
    for a given observation sequence.

    Parameters
    ----------
    n_frames : int or float
        Number of exposures.
    exp_t : float
        Individual frame exposure time in seconds.
    mode : str, optional
        Observation mode - if set to 'continuous' (default), the
        total wall clock time is computed assuming continuous reads 
        with frame transfer at the end. This is the standard for 'science'
        observations. If not set to continuous, it is assumed that each
        frame takes a frame transfer time hit. This is generally the 
        assumed mode for unocculted calibration observations.
    readout_t : float, optional
        Single EXCAM exposure readout time in seconds. Default is 0.264.
    transfer_time : float, optional
        EXCAM Science frame transfer time in seconds. Default is 3.0.

    Returns
    -------
    float
        Total wall clock time in seconds.

    Notes
    -----
    EXCAM has a 0.264 second read time for SCI-sized frames.
    In continuous exposure mode, EXCAM frames can only be transferred once
    every 3 seconds due to data rate limitations. Very short exposures
    will have large overheads!
    
    EETC has a more accurate version built in for fixed-integration-time
    calculation for using EXCAM in "burst" mode.
    
    For SCI observations, transfer occurs while exposing (no n_frames * transfer_time penalty). 
    
    For CAL observations, frames are read out after each exposure and transferred in bulk at the end
    (includes n_frames * readout_time and n_frames * transfer_time penalty).
    """
    # SCI observations are reading out while exposing
    # (no n_frames * readout_time penalty)
    if mode == 'continuous':
        if exp_t < transfer_time:
            frame_t = transfer_time + readout_t 
        else:
            frame_t = exp_t + readout_t
        return frame_t * n_frames + transfer_time
    # CALIBRATION observations take the n_frames * (readout_time + transfer_time) penalty
    else:
        frame_t = exp_t + readout_t
        return n_frames * (frame_t + transfer_time)

# %% [markdown]
# ### Gaussian at 5e-7

# %%
nframes = 5
camparams_nom = {
    0: {"cam_gain": 1180.9492, "cam_exptime": 27.8345, "cam_nframes": nframes},   # subband 0
    1: {"cam_gain": 1148.4279, "cam_exptime": 34.4994, "cam_nframes": nframes},   # subband 1
    2: {"cam_gain": 1200.4989, "cam_exptime": 40.3357, "cam_nframes": nframes},   # subband 2
}
 
camparams_probe = {
    0: {"cam_gain": 280.7582, "cam_exptime": 18.9388, "cam_nframes": nframes},   # subband 0
    1: {"cam_gain": 284.5764, "cam_exptime": 21.1977, "cam_nframes": nframes},   # subband 1
    2: {"cam_gain": 290.9951, "cam_exptime": 24.0980, "cam_nframes": nframes},   # subband 2
}

# %%
# Total time WITHOUT overheads
t_total = {}
for subband in range(3):
    t_unprobed = camparams_nom[subband]['cam_nframes'] * camparams_nom[subband]['cam_exptime']
    t_sat_spots = camparams_probe[subband]['cam_nframes'] * camparams_probe[subband]['cam_exptime']

    t_total[subband] = t_unprobed + 3*3*t_sat_spots # sat spots takes +/-/0 and there are 3 sat spot shapes

    print(f'subband {subband} total time [s]: {t_total[subband]}')
    print(f'subband {subband} total time [hrs]: {t_total[subband]/3600}')

# %%
# Total time WITH overheads
t_total = {}
for subband in range(3):
    t_unprobed = rough_wall_clock(camparams_nom[subband]['cam_nframes'],
                                 camparams_nom[subband]['cam_exptime'],
                                 mode='continuous')
    t_sat_spots = rough_wall_clock(camparams_probe[subband]['cam_nframes'],
                                     camparams_probe[subband]['cam_exptime'],
                                     mode='not_continuous')

    t_total[subband] = t_unprobed + 3*3*t_sat_spots # sat spots takes +/-/0 and there are 3 sat spot shapes

    print(f'subband {subband} total time [s]: {t_total[subband]}')
    print(f'subband {subband} total time [hrs]: {t_total[subband]/3600}')

# %% [markdown]
# ### Default probes at 5e-7

# %%
nframes = 5
camparams_nom = {
    0: {"cam_gain": 1233.0312, "cam_exptime": 26.9076, "cam_nframes": nframes},   # subband 0
    1: {"cam_gain": 1140.3127, "cam_exptime": 32.3539, "cam_nframes": nframes},   # subband 1
    2: {"cam_gain": 1232.1592, "cam_exptime": 38.6610, "cam_nframes": nframes},   # subband 2
}
 
camparams_probe = {
    0: {"cam_gain": 283.3207, "cam_exptime": 18.8891, "cam_nframes": nframes},   # subband 0
    1: {"cam_gain": 279.7209, "cam_exptime": 21.1038, "cam_nframes": nframes},   # subband 1
    2: {"cam_gain": 291.1015, "cam_exptime": 24.0291, "cam_nframes": nframes},   # subband 2
}

# %%
# Total time WITHOUT overheads
t_total = {}
for subband in range(3):
    t_unprobed = camparams_nom[subband]['cam_nframes'] * camparams_nom[subband]['cam_exptime']
    t_sat_spots = camparams_probe[subband]['cam_nframes'] * camparams_probe[subband]['cam_exptime']

    t_total[subband] = t_unprobed + 3*3*t_sat_spots # sat spots takes +/-/0 and there are 3 sat spot shapes

    print(f'subband {subband} total time [s]: {t_total[subband]}')
    print(f'subband {subband} total time [hrs]: {t_total[subband]/3600}')

# %%
# Total time WITH overheads
t_total = {}
for subband in range(3):
    t_unprobed = rough_wall_clock(camparams_nom[subband]['cam_nframes'],
                                 camparams_nom[subband]['cam_exptime'],
                                 mode='continuous')
    t_sat_spots = rough_wall_clock(camparams_probe[subband]['cam_nframes'],
                                     camparams_probe[subband]['cam_exptime'],
                                     mode='not_continuous')

    t_total[subband] = t_unprobed + 3*3*t_sat_spots # sat spots takes +/-/0 and there are 3 sat spot shapes

    print(f'subband {subband} total time [s]: {t_total[subband]}')
    print(f'subband {subband} total time [hrs]: {t_total[subband]/3600}')

# %% [markdown]
# ### Gaussian at 1e-7

# %%
camparams_nom = {
    0: {"cam_gain": 635, "cam_exptime": 47, "cam_nframes": 6},   # subband 0
    1: {"cam_gain": 700, "cam_exptime": 47, "cam_nframes": 6},   # subband 1
    2: {"cam_gain": 700, "cam_exptime": 47, "cam_nframes": 6},   # subband 2
}
 
camparams_probe = {
    0: {"cam_gain": 169, "cam_exptime": 45, "cam_nframes": 5},   # subband 0
    1: {"cam_gain": 181, "cam_exptime": 47, "cam_nframes": 5},   # subband 1
    2: {"cam_gain": 181, "cam_exptime": 47, "cam_nframes": 5},   # subband 2
}

# %%
# Total time WITHOUT overheads
t_total = {}
for subband in range(3):
    t_unprobed = camparams_nom[subband]['cam_nframes'] * camparams_nom[subband]['cam_exptime']
    t_sat_spots = camparams_probe[subband]['cam_nframes'] * camparams_probe[subband]['cam_exptime']

    t_total[subband] = t_unprobed + 3*3*t_sat_spots # sat spots takes +/-/0 and there are 3 sat spot shapes

    print(f'subband {subband} total time [s]: {t_total[subband]}')
    print(f'subband {subband} total time [hrs]: {t_total[subband]/3600}')

# %%
# Total time WITH overheads
t_total = {}
for subband in range(3):
    t_unprobed = rough_wall_clock(camparams_nom[subband]['cam_nframes'],
                                 camparams_nom[subband]['cam_exptime'],
                                 mode='continuous')
    t_sat_spots = rough_wall_clock(camparams_probe[subband]['cam_nframes'],
                                     camparams_probe[subband]['cam_exptime'],
                                     mode='not_continuous')

    t_total[subband] = t_unprobed + 3*3*t_sat_spots # sat spots takes +/-/0 and there are 3 sat spot shapes

    print(f'subband {subband} total time [s]: {t_total[subband]}')
    print(f'subband {subband} total time [hrs]: {t_total[subband]/3600}')

# %% [markdown]
# ### Default probes at 1e-7

# %%
camparams_nom = {
    0: {"cam_gain": 216, "cam_exptime": 46, "cam_nframes": 4},
    1: {"cam_gain": 392, "cam_exptime": 46, "cam_nframes": 5},
    2: {"cam_gain": 345, "cam_exptime": 46, "cam_nframes": 6},
}

camparams_probe = {
    0: {"cam_gain": 118, "cam_exptime": 46, "cam_nframes": 5},
    1: {"cam_gain": 184, "cam_exptime": 46, "cam_nframes": 5},
    2: {"cam_gain": 175, "cam_exptime": 46, "cam_nframes": 5},
}

# %%
# Total time WITHOUT overheads
t_total = {}
for subband in range(3):
    t_unprobed = camparams_nom[subband]['cam_nframes'] * camparams_nom[subband]['cam_exptime']
    t_sat_spots = camparams_probe[subband]['cam_nframes'] * camparams_probe[subband]['cam_exptime']

    t_total[subband] = t_unprobed + 3*3*t_sat_spots # sat spots takes +/-/0 and there are 3 sat spot shapes

    print(f'subband {subband} total time [s]: {t_total[subband]}')
    print(f'subband {subband} total time [hrs]: {t_total[subband]/3600}')

# %%
# Total time WITH overheads
t_total = {}
for subband in range(3):
    t_unprobed = rough_wall_clock(camparams_nom[subband]['cam_nframes'],
                                 camparams_nom[subband]['cam_exptime'],
                                 mode='continuous')
    t_sat_spots = rough_wall_clock(camparams_probe[subband]['cam_nframes'],
                                     camparams_probe[subband]['cam_exptime'],
                                     mode='not_continuous')

    t_total[subband] = t_unprobed + 3*3*t_sat_spots # sat spots takes +/-/0 and there are 3 sat spot shapes

    print(f'subband {subband} total time [s]: {t_total[subband]}')
    print(f'subband {subband} total time [hrs]: {t_total[subband]/3600}')
